# %%
import numpy as np

import py5

# %%
# %load_ext py5

# %%
size = 100
n = size
fill_colors = 255 * np.random.rand(n, 3)
max_rect_size = 50

# %%
def random_rectangle_size():
    return max_rect_size * np.random.rand(), max_rect_size * np.random.rand()

# %%
# %%py5drawsvg 500 500
#
# for i in range(n):
#     fill(*fill_colors[i])
#     rect(width * np.random.rand(), height * np.random.rand(), *random_rectangle_size())
# Out:
# WARNING: py5 name conflict detected with "size"
# shutdown called

# %%
# %%py5drawsvg?
